# %% [markdown]
# <a href="https://colab.research.google.com/github/joagv/Curso-Python-2023/blob/main/Actividad_11_Ch11_Turtle.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip3 install ColabTurtle
# Out:
# ...
#   Preparing metadata (setup.py) ... done
# ...
#   Created wheel for ColabTurtle: filename=ColabTurtle-2.1.0-py3-none-any.whl size=7642 sha256=c4d5a2795ba7de35594753522c3541988090a078c8b5e537da71423a42a69994
#   Stored in directory: /root/.cache/pip/wheels/5b/86/e8/54f5c8c853606e3a3060bb2e60363cbed632374a12e0f33ffc
# Successfully built ColabTurtle
# ...

# %%
from ColabTurtle.Turtle import *

# %%
import ColabTurtle

# %%
initializeTurtle(initial_speed=10)
colors_list = ["red", "orange", "yellow"]

for value in range(450):
  pencolor(colors_list[value%3])
  width(int(value/100) + 1)
  forward(value/1.5)
  left(140)
# Out:
#       <svg width="800" height="500">
#         <rect width="100%" height="100%" fill="black"/>
# ...
